# %% [markdown]
# # Research Methods Hackathon

# %%
# ============================================================
# CELL 1 — PROJECT PATH SETUP
# ============================================================

from pathlib import Path

PROJECT_ROOT = Path(r"C:\Users\girid\OneDrive\Desktop\Research Methods Hackathon")

DATA_DIR = PROJECT_ROOT / "Data"
NOTEBOOK_DIR = PROJECT_ROOT / "Notebook"
OUTPUTS_DIR = PROJECT_ROOT / "Outputs"
PLOTS_DIR = OUTPUTS_DIR / "Plots"
RESULTS_DIR = PROJECT_ROOT / "Results csv"

for folder in [DATA_DIR, NOTEBOOK_DIR, OUTPUTS_DIR, PLOTS_DIR, RESULTS_DIR]:
    folder.mkdir(parents=True, exist_ok=True)

print("Project structure ready.")
print("Data:", DATA_DIR)
print("Plots:", PLOTS_DIR)
print("Results:", RESULTS_DIR)
# Out:
# Project structure ready.
# Data: C:\Users\girid\OneDrive\Desktop\Research Methods Hackathon\Data
# Plots: C:\Users\girid\OneDrive\Desktop\Research Methods Hackathon\Outputs\Plots
# Results: C:\Users\girid\OneDrive\Desktop\Research Methods Hackathon\Results csv

# %%
# ============================================================
# CELL 2 — IMPORT LIBRARIES
# ============================================================

import warnings
warnings.filterwarnings("ignore")

import re
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, classification_report,
    confusion_matrix
)

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

pd.set_option("display.max_columns", None)

# Colourful theme — avoids default blue
sns.set_theme(style="whitegrid", palette="Set2")

RANDOM_STATE = 42

# %%
# ============================================================
# CELL 3 — SAVE PLOT FUNCTION
# ============================================================

def save_plot(filename):
    path = PLOTS_DIR / filename
    plt.savefig(path, dpi=300, bbox_inches="tight")
    print(f"Saved plot: {path}")

# %%
# CELL 4 — LOAD DATA

# %%
# CELL 5 — DATASET OVERVIEW

# %%
# CELL 6 — TARGET DISTRIBUTION

# %%
# CELL 7 — MISSING VALUE ANALYSIS

# %%
# CELL 8 — IMPORTANT FEATURE ANALYSIS

# %%
# CELL 9 — FEATURE VS TARGET FUNCTION

# %%
# CELL 10 — RUN EDA

# %%
# CELL 11 — CORRELATION HEATMAP

# %%
# CELL 12 — PREPARE FEATURES AND TARGET

# %%
# CELL 13 — HANDLE MISSING VALUES

# %%
# CELL 14 — ONE-HOT ENCODING

# %%
# CELL 15 — CLEAN FEATURE NAMES

# %%
# CELL 16 — TRAIN VALIDATION SPLIT

# %%
# CELL 17 — MODEL EVALUATION FUNCTION

# %%
# CELL 18 — LOGISTIC REGRESSION

# %%
# CELL 19 — RANDOM FOREST

# %%
# CELL 20 — GRADIENT BOOSTING

# %%
# CELL 21 — KNN

# %%
# CELL 22 — SVM

# %%
# CELL 23 — MODEL COMPARISON

# %%
# CELL 24 — MODEL COMPARISON PLOT

# %%
# CELL 25 — FEATURE IMPORTANCE

# %%
# CELL 26 — SAVE PREDICTION FILES

# %%
# CELL 27 — FINAL SUMMARY
